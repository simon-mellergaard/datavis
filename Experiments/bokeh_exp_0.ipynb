# %%
#Check version
import bokeh
print(bokeh.__version__)
# Out:
# 3.7.0

# %%
##Working version with label names (another version below):
# === FINAL DASHBOARD: Dropdown + Selection + Axis Labels ===
import panel as pn
import pandas as pd
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
pn.extension('bokeh')

# --- Load & clean ---
df = pd.read_excel("../data/DATA_UFM_combined.xlsx")
plot_cols = ['tidsforbrug_p50', 'ensom_likert', 'arbejdstid_timer', 'maanedloen_10aar', 'titel']

df['hovedinsttx'] = df['hovedinsttx'].astype(str).str.strip()
df = df[df['hovedinsttx'].str.lower() != 'nan']
df_clean = df.dropna(subset=plot_cols + ['hovedinsttx'])

categories = sorted(df_clean['hovedinsttx'].unique())

# --- Dropdown ---
dropdown = pn.widgets.Select(name="Hovedinstitution", options=categories, value=categories[0])

# --- Sources ---
source_main = ColumnDataSource(df_clean[df_clean['hovedinsttx'] == categories[0]][plot_cols])
source_selected = ColumnDataSource(data={c: [] for c in plot_cols})

# --- Plot 1: Tidsforbrug vs Ensomhed ---
p1 = figure(
    title="Tidsforbrug vs Ensomhed",
    width=500, height=400,
    tools="pan,wheel_zoom,box_select,lasso_select,reset",
    tooltips=[
        ("Tidsforbrug", "@tidsforbrug_p50"),
        ("Ensomhed", "@ensom_likert"),
        ("Titel", "@titel")
    ]
)
p1.circle('tidsforbrug_p50', 'ensom_likert', size=8, source=source_main,
          selection_color="orange", nonselection_alpha=0.3)

# AXIS LABELS
p1.xaxis.axis_label = "Tidsforbrug (p50)"
p1.yaxis.axis_label = "Ensomhed (Likert)"

# --- Plot 2: Arbejdstid vs Månedsløn (valgte) ---
p2 = figure(
    title="Valgte: Arbejdstid vs Månedsløn",
    width=500, height=400,
    tooltips=[
        ("Timer", "@arbejdstid_timer"),
        ("Løn", "@maanedloen_10aar"),
        ("Titel", "@titel")
    ]
)
p2.square('arbejdstid_timer', 'maanedloen_10aar', size=8, color="red", source=source_selected)

# AXIS LABELS
p2.xaxis.axis_label = "Arbejdstid (timer/uge)"
p2.yaxis.axis_label = "Månedsløn (10-års niveau)"

# --- Dropdown update ---
@pn.depends(dropdown.param.value, watch=True)
def update_main_plot(cat):
    filtered = df_clean[df_clean['hovedinsttx'] == cat][plot_cols]
    source_main.data = filtered.to_dict('list')
    source_selected.data = {c: [] for c in plot_cols}
    p1.title.text = f"{10}"

# --- Selection update ---
def update_selected(event=None):
    indices = source_main.selected.indices
    if indices:
        selected_df = pd.DataFrame(source_main.data).iloc[indices]
        source_selected.data = selected_df[plot_cols].to_dict('list')
    else:
        source_selected.data = {c: [] for c in plot_cols}

source_main.selected.on_change('indices', lambda attr, old, new: update_selected())

# --- Layout ---
dashboard = pn.Column(
    dropdown,
    pn.Row(p1, p2)
)

dashboard.servable()
# Out:
# WARNING:param.panel_extension: bokeh extension not recognized and will be skipped.
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='550ad630-cb22-42d0-b174-0a0da0b0cc3f'>
#   <div id="a1109dc5-c4d9-4e44-a519-30997dac342c" data-root-id="550ad630-cb22-42d0-b174-0a0da0b0cc3f" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
#Bidirectional highlighting
# === FINAL: BI-DIRECTIONAL + TOOLBARS VISIBLE + NO ERRORS ===
import panel as pn
import pandas as pd
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

pn.extension('bokeh')

# --- Load & clean ---
df = pd.read_excel("../data/DATA_UFM_combined.xlsx")
plot_cols = ['tidsforbrug_p50', 'ensom_likert', 'arbejdstid_timer', 'maanedloen_10aar', 'titel']

df['hovedinsttx'] = df['hovedinsttx'].astype(str).str.strip()
df = df[df['hovedinsttx'].str.lower() != 'nan']
df_clean = df.dropna(subset=plot_cols + ['hovedinsttx'])

categories = sorted(df_clean['hovedinsttx'].unique())

# --- Dropdown ---
dropdown = pn.widgets.Select(name="Hovedinstitution", options=categories, value=categories[0])

# --- SHARED SOURCE ---
source = ColumnDataSource(df_clean[df_clean['hovedinsttx'] == categories[0]][plot_cols])

# --- Plot 1 ---
p1 = figure(
    title="Tidsforbrug vs Ensomhed",
    width=500, height=400,
    tools="pan,wheel_zoom,box_select,lasso_select,reset",  # ← FIXED
    toolbar_location="above",
    tooltips=[
        ("Tidsforbrug", "@tidsforbrug_p50"),
        ("Ensomhed", "@ensom_likert"),
        ("Titel", "@titel")
    ]
)
p1.circle('tidsforbrug_p50', 'ensom_likert', size=8, source=source,
          selection_color="orange", nonselection_alpha=0.3)

p1.xaxis.axis_label = "Tidsforbrug (p50)"
p1.yaxis.axis_label = "Ensomhed (Likert)"

# --- Plot 2 ---
p2 = figure(
    title="Arbejdstid vs Månedsløn",
    width=500, height=400,
    tools="pan,wheel_zoom,box_select,lasso_select,reset",  # ← FIXED
    toolbar_location="above",
    tooltips=[
        ("Timer", "@arbejdstid_timer"),
        ("Løn", "@maanedloen_10aar"),
        ("Titel", "@titel")
    ]
)
p2.circle('arbejdstid_timer', 'maanedloen_10aar', size=8, source=source,
          selection_color="orange", nonselection_alpha=0.3)

p2.xaxis.axis_label = "Arbejdstid (timer/uge)"
p2.yaxis.axis_label = "Månedsløn (10-års niveau)"

# --- Dropdown update ---
@pn.depends(dropdown.param.value, watch=True)
def update_plots(cat):
    filtered = df_clean[df_clean['hovedinsttx'] == cat][plot_cols]
    source.data = filtered.to_dict('list')
    p1.title.text = f"{cat} ({len(filtered)} points)"
    p2.title.text = f"{cat} ({len(filtered)} points)"

# --- BI-DIRECTIONAL SELECTION (auto via shared source) ---
source.selected.on_change('indices', lambda attr, old, new: None)

# --- Layout ---
dashboard = pn.Column(
    dropdown,
    pn.Row(p1, p2, sizing_mode="stretch_both")
)

dashboard.servable()
# Out:
# WARNING:param.panel_extension: bokeh extension not recognized and will be skipped.
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='083686c0-d766-4735-866b-7c2535c5cfd3'>
#   <div id="a1e0a636-389e-4f56-a9b7-96ddfac9800b" data-root-id="083686c0-d766-4735-866b-7c2535c5cfd3" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
#Same as above, but html version so it's fully visible. Prints to dashboard.html:
# === SAVE AS HTML: Full Interactive Dashboard in Browser ===
import panel as pn
import pandas as pd
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure

pn.extension('bokeh')

# --- Load & clean ---
df = pd.read_excel("../data/DATA_UFM_combined.xlsx")
plot_cols = ['tidsforbrug_p50', 'ensom_likert', 'arbejdstid_timer', 'maanedloen_10aar', 'titel']

df['hovedinsttx'] = df['hovedinsttx'].astype(str).str.strip()
df = df[df['hovedinsttx'].str.lower() != 'nan']
df_clean = df.dropna(subset=plot_cols + ['hovedinsttx'])

categories = sorted(df_clean['hovedinsttx'].unique())

# --- Dropdown ---
dropdown = pn.widgets.Select(name="Hovedinstitution", options=categories, value=categories[0])

# --- SHARED SOURCE ---
source = ColumnDataSource(df_clean[df_clean['hovedinsttx'] == categories[0]][plot_cols])

# --- Plot 1 ---
p1 = figure(
    title="Tidsforbrug vs Ensomhed",
    width=600, height=500,  # ← Bigger for browser
    tools="pan,wheel_zoom,box_select,lasso_select,reset",
    toolbar_location="above",
    tooltips=[
        ("Tidsforbrug", "@tidsforbrug_p50"),
        ("Ensomhed", "@ensom_likert"),
        ("Titel", "@titel")
    ]
)
p1.circle('tidsforbrug_p50', 'ensom_likert', size=8, source=source,
          selection_color="orange", nonselection_alpha=0.3)

p1.xaxis.axis_label = "Tidsforbrug (p50)"
p1.yaxis.axis_label = "Ensomhed (Likert)"

# --- Plot 2 ---
p2 = figure(
    title="Arbejdstid vs Månedsløn",
    width=600, height=500,  # ← Bigger
    tools="pan,wheel_zoom,box_select,lasso_select,reset",
    toolbar_location="above",
    tooltips=[
        ("Timer", "@arbejdstid_timer"),
        ("Løn", "@maanedloen_10aar"),
        ("Titel", "@titel")
    ]
)
p2.circle('arbejdstid_timer', 'maanedloen_10aar', size=8, source=source,
          selection_color="orange", nonselection_alpha=0.3)

p2.xaxis.axis_label = "Arbejdstid (timer/uge)"
p2.yaxis.axis_label = "Månedsløn (10-års niveau)"

# --- Dropdown update ---
@pn.depends(dropdown.param.value, watch=True)
def update_plots(cat):
    filtered = df_clean[df_clean['hovedinsttx'] == cat][plot_cols]
    source.data = filtered.to_dict('list')
    p1.title.text = f"{cat} ({len(filtered)} points)"
    p2.title.text = f"{cat} ({len(filtered)} points)"

# --- BI-DIRECTIONAL SELECTION ---
source.selected.on_change('indices', lambda attr, old, new: None)

# --- Layout ---
dashboard = pn.Column(
    dropdown,
    pn.Row(p1, p2, sizing_mode="stretch_both"),
    sizing_mode="stretch_width"
)

# --- SAVE TO HTML (FULL BROWSER EXPERIENCE) ---
dashboard.save("dashboard.html", embed=True)

print("Dashboard saved to 'dashboard.html'")
print("Open it in your browser for full interactive view!")
# Out:
# WARNING:param.panel_extension: bokeh extension not recognized and will be skipped.
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='6abeb2d6-e2ec-46a8-857a-824b0b31d243'>
#   <div id="b897250b-a2c5-4b3f-9a13-94e866e1c5d2" data-root-id="6abeb2d6-e2ec-46a8-857a-824b0b31d243" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
#This version apps a clickable map, that toggles which institutions you can see
#It also matches that logic to the plots - i.e DMJX has programs in both Aarhus and KBH
#But it only shows the ones relevant for what you've clicked on
#It also adds tap to highlight, and holding shift allows you to highlight more points

import pandas as pd
import requests
import json
from bokeh.models import (
    ColumnDataSource, GeoJSONDataSource, HoverTool, CustomJS, Button, Select, TapTool
)
from bokeh.plotting import figure, output_file, save
from bokeh.layouts import column, row

# --- Load data ---
df = pd.read_excel("../data/DATA_UFM_combined.xlsx")
plot_cols = [
    'tidsforbrug_p50', 'ensom_likert', 'arbejdstid_timer',
    'maanedloen_10aar', 'hovedinsttx', 'instkommunetx', 'titel'
]
df_clean = df.dropna(subset=plot_cols)

# Normalize strings
df_clean['instkommunetx'] = df_clean['instkommunetx'].astype(str).str.strip()
df_clean['hovedinsttx'] = df_clean['hovedinsttx'].astype(str).str.strip()

# All institutions
all_institutions = sorted(df_clean['hovedinsttx'].unique())

# Kommuner present in dataset (lowercase)
kommuner_in_data = set(df_clean['instkommunetx'].str.lower())

# --- Fetch GeoJSON (all kommuner) ---
response = requests.get("https://api.dataforsyningen.dk/kommuner?format=geojson")
geojson_data = response.json()

# Annotate features
for feat in geojson_data['features']:
    navn = feat['properties'].get('navn', '').strip().lower()
    clickable = navn in kommuner_in_data
    feat['properties']['clickable'] = bool(clickable)
    feat['properties']['selected'] = False
    feat['properties']['fill_color'] = 'lightblue' if clickable else 'lightgrey'

geojson_str = json.dumps(geojson_data)

# --- Data sources ---
full_data = ColumnDataSource(df_clean)        # master copy for filtering
source_scatter = ColumnDataSource(df_clean)   # scatter plot data
source_municipalities = GeoJSONDataSource(geojson=geojson_str)

# --- Widgets ---
dropdown = Select(title="Hovedinstitution", value=all_institutions[0], options=all_institutions)
reset_button = Button(label="Reset All", button_type="success", width=100)

# --- Map plot ---
map_plot = figure(
    title="Click a Kommune to Filter Institutions (toggle multi-select)",
    width=600, height=600,
    tools="tap,reset",
    toolbar_location="above"
)

patches = map_plot.patches(
    'xs', 'ys', source=source_municipalities,
    fill_color='fill_color',
    line_color="blue", line_width=1.0,
    fill_alpha=0.85,
    nonselection_alpha=0.4
)
hover_map = HoverTool(renderers=[patches], tooltips=[("Kommune", "@navn")])
map_plot.add_tools(hover_map)

# --- Scatter plots with hover tooltips + tap multi-select ---
hover_tool_p1 = HoverTool(tooltips=[
    ("Tidsforbrug", "@tidsforbrug_p50"),
    ("Ensomhed", "@ensom_likert"),
    ("Titel", "@titel"),
    ("Kommune", "@instkommunetx")
])
hover_tool_p2 = HoverTool(tooltips=[
    ("Timer", "@arbejdstid_timer"),
    ("Løn", "@maanedloen_10aar"),
    ("Titel", "@titel"),
    ("Kommune", "@instkommunetx")
])

p1 = figure(
    title="Tidsforbrug vs Ensomhed",
    width=400, height=400,
    tools="pan,wheel_zoom,box_select,lasso_select,reset",
    toolbar_location="above"
)
p1.add_tools(hover_tool_p1)
tap1 = TapTool()  # default: Shift+click allows multi-selection
p1.add_tools(tap1)
p1.circle('tidsforbrug_p50', 'ensom_likert', size=8, source=source_scatter,
          selection_color="orange", nonselection_alpha=0.3)

p2 = figure(
    title="Arbejdstid vs Månedsløn",
    width=400, height=400,
    tools="pan,wheel_zoom,box_select,lasso_select,reset",
    toolbar_location="above"
)
p2.add_tools(hover_tool_p2)
tap2 = TapTool()
p2.add_tools(tap2)
p2.circle('arbejdstid_timer', 'maanedloen_10aar', size=8, source=source_scatter,
          selection_color="orange", nonselection_alpha=0.3)

# --- JS: map selection callback (cross-filter + highlight) ---
map_callback = CustomJS(args=dict(
    source_scatter=source_scatter,
    source_municipalities=source_municipalities,
    dropdown=dropdown,
    full_data=full_data
), code="""
    const geojson = JSON.parse(source_municipalities.geojson);
    const inds = cb_obj.indices;

    // Toggle selected kommuner (Shift behavior automatic handled in Bokeh)
    inds.forEach(i => {
        const feat = geojson.features[i];
        if (feat.properties.clickable) {
            feat.properties.selected = !feat.properties.selected;
        }
    });

    // Update fill colors
    geojson.features.forEach(f => {
        if (!f.properties.clickable) {
            f.properties.fill_color = 'lightgrey';
        } else if (f.properties.selected) {
            f.properties.fill_color = 'orange';
        } else {
            f.properties.fill_color = 'lightblue';
        }
    });
    source_municipalities.geojson = JSON.stringify(geojson);

    // Get selected kommuner
    const selected_kommuner = geojson.features
        .filter(f => f.properties.selected)
        .map(f => f.properties.navn.toLowerCase());

    const data_all = full_data.data;
    const keys = Object.keys(data_all);

    // Cross-filter by both dropdown and selected kommuner
    const selected_inst = dropdown.value;
    const keep = [];
    for (let i=0; i<data_all['instkommunetx'].length; i++) {
        const row_komm = (data_all['instkommunetx'][i] || '').toLowerCase();
        const row_inst = data_all['hovedinsttx'][i];
        if ((selected_kommuner.length === 0 || selected_kommuner.includes(row_komm)) &&
            row_inst === selected_inst) keep.push(i);
    }

    // Rebuild filtered data
    const new_data = {};
    for (let k=0; k<keys.length; k++) {
        const key = keys[k];
        new_data[key] = keep.map(i => data_all[key][i]);
    }
    source_scatter.data = new_data;

    // Update dropdown to only institutions in selected kommuner
    const inst_set = Array.from(new Set(
        data_all['hovedinsttx'].filter((val,i) => 
            selected_kommuner.length===0 || selected_kommuner.includes((data_all['instkommunetx'][i]||'').toLowerCase()))
    )).sort();
    dropdown.options = inst_set;
    if (inst_set.length>0 && !inst_set.includes(selected_inst)) dropdown.value = inst_set[0];

    source_scatter.change.emit();
""")
patches.data_source.selected.js_on_change('indices', map_callback)

# --- JS: dropdown callback (cross-filter by selected kommuner) ---
dropdown_callback = CustomJS(args=dict(
    source_scatter=source_scatter,
    full_data=full_data,
    source_municipalities=source_municipalities
), code="""
    const val = cb_obj.value;
    const data_all = full_data.data;
    const keys = Object.keys(data_all);

    // Selected kommuner from map
    const geojson = JSON.parse(source_municipalities.geojson);
    const selected_kommuner = geojson.features
        .filter(f => f.properties.selected)
        .map(f => f.properties.navn.toLowerCase());

    const keep = [];
    for (let i=0; i<data_all['hovedinsttx'].length; i++) {
        const row_inst = data_all['hovedinsttx'][i];
        const row_komm = (data_all['instkommunetx'][i] || '').toLowerCase();
        if (row_inst === val && (selected_kommuner.length===0 || selected_kommuner.includes(row_komm))) keep.push(i);
    }

    const new_data = {};
    for (let k=0; k<keys.length; k++) {
        const key = keys[k];
        new_data[key] = keep.map(i => data_all[key][i]);
    }
    source_scatter.data = new_data;
    source_scatter.change.emit();
""")
dropdown.js_on_change('value', dropdown_callback)

# --- Reset button JS (resets selection + zoom) ---
reset_callback = CustomJS(args=dict(
    source_scatter=source_scatter,
    source_municipalities=source_municipalities,
    dropdown=dropdown,
    full_data=full_data,
    p1=p1, p2=p2
), code="""
    // Reset map
    const geojson = JSON.parse(source_municipalities.geojson);
    geojson.features.forEach(f => {
        f.properties.selected = false;
        f.properties.fill_color = f.properties.clickable ? 'lightblue' : 'lightgrey';
    });
    source_municipalities.geojson = JSON.stringify(geojson);

    // Reset scatter plots
    const data_all = full_data.data;
    source_scatter.data = Object.assign({}, data_all);

    // Reset dropdown
    const all_insts = Array.from(new Set(data_all['hovedinsttx'])).sort();
    dropdown.options = all_insts;
    dropdown.value = all_insts[0];

    // Reset zoom ranges
    p1.reset.emit();
    p2.reset.emit();

    source_scatter.change.emit();
""")
reset_button.js_on_click(reset_callback)

# --- Layout & save ---
layout = column(row(dropdown, reset_button), row(map_plot, column(p1, p2)))
output_file("kommune_dashboard.html")
save(layout)
print("Dashboard saved to 'dashboard_map.html' — multiselect, hover, tap multi-select, cross-filtered")
# Out:
# C:\Users\whart\AppData\Local\Temp\ipykernel_24088\1976824772.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['instkommunetx'] = df_clean['instkommunetx'].astype(str).str.strip()
# C:\Users\whart\AppData\Local\Temp\ipykernel_24088\1976824772.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['hovedinsttx'] = df_clean['hovedinsttx'].astype(str).str.strip()
# ...
# Dashboard saved to 'dashboard_map.html' — multiselect, hover, tap multi-select, cross-filtered

# %%
#This version adds search for programs
#Logic is build such that you can only search for programs visible in the plot
#Seaching then highlights the program, using the same logic as clicking on it
#Searching for more items, adds them to the highlighted items
#Clicking (unless you hold shift) then deselects, just like box/lasso select also does
#Hence it hopefully works as expected
import pandas as pd
import requests
import json
from bokeh.models import (
    ColumnDataSource, GeoJSONDataSource, HoverTool, CustomJS, Button, Select, TapTool,
    AutocompleteInput
)
from bokeh.plotting import figure, output_file, save
from bokeh.layouts import column, row

# --- Load data ---
df = pd.read_excel("../data/DATA_UFM_combined.xlsx")
plot_cols = [
    'tidsforbrug_p50', 'ensom_likert', 'arbejdstid_timer',
    'maanedloen_10aar', 'hovedinsttx', 'instkommunetx', 'titel'
]
df_clean = df.dropna(subset=plot_cols)

# Normalize strings
df_clean['instkommunetx'] = df_clean['instkommunetx'].astype(str).str.strip()
df_clean['hovedinsttx'] = df_clean['hovedinsttx'].astype(str).str.strip()
df_clean['titel'] = df_clean['titel'].astype(str).str.strip()

# All institutions
all_institutions = sorted(df_clean['hovedinsttx'].unique())

# Kommuner present in dataset (lowercase)
kommuner_in_data = set(df_clean['instkommunetx'].str.lower())

# --- Fetch GeoJSON (all kommuner) ---
response = requests.get("https://api.dataforsyningen.dk/kommuner?format=geojson")
geojson_data = response.json()

# Annotate features
for feat in geojson_data['features']:
    navn = feat['properties'].get('navn', '').strip().lower()
    clickable = navn in kommuner_in_data
    feat['properties']['clickable'] = bool(clickable)
    feat['properties']['selected'] = False
    feat['properties']['fill_color'] = 'lightblue' if clickable else 'lightgrey'

geojson_str = json.dumps(geojson_data)

# --- Data sources ---
full_data = ColumnDataSource(df_clean)        # master copy
source_scatter = ColumnDataSource(df_clean)   # scatter plot data
source_municipalities = GeoJSONDataSource(geojson=geojson_str)

# --- Widgets ---
dropdown = Select(title="Hovedinstitution", value=all_institutions[0], options=all_institutions)
reset_button = Button(label="Reset All", button_type="success", width=100)
search_input = AutocompleteInput(title="Search Titel:", completions=[], min_characters=0, placeholder="Search to highlight...")

# --- Map plot ---
map_plot = figure(
    title="Click a Kommune to Filter Institutions (toggle multi-select)",
    width=600, height=600,
    tools="tap,reset",
    toolbar_location="above"
)
patches = map_plot.patches(
    'xs', 'ys', source=source_municipalities,
    fill_color='fill_color',
    line_color="blue", line_width=1.0,
    fill_alpha=0.85,
    nonselection_alpha=0.4
)
hover_map = HoverTool(renderers=[patches], tooltips=[("Kommune", "@navn")])
map_plot.add_tools(hover_map)

# --- Scatter plots ---
hover_tool_p1 = HoverTool(tooltips=[("Tidsforbrug", "@tidsforbrug_p50"),
                                    ("Ensomhed", "@ensom_likert"),
                                    ("Titel", "@titel"),
                                    ("Kommune", "@instkommunetx")])
hover_tool_p2 = HoverTool(tooltips=[("Timer", "@arbejdstid_timer"),
                                    ("Løn", "@maanedloen_10aar"),
                                    ("Titel", "@titel"),
                                    ("Kommune", "@instkommunetx")])

p1 = figure(title="Tidsforbrug vs Ensomhed", width=400, height=400,
            tools="pan,wheel_zoom,box_select,lasso_select,reset",
            toolbar_location="above")
p1.add_tools(hover_tool_p1)
tap1 = TapTool()
p1.add_tools(tap1)
p1_glyph = p1.circle('tidsforbrug_p50', 'ensom_likert', size=8, source=source_scatter,
          selection_color="orange", nonselection_alpha=0.3)

p2 = figure(title="Arbejdstid vs Månedsløn", width=400, height=400,
            tools="pan,wheel_zoom,box_select,lasso_select,reset",
            toolbar_location="above")
p2.add_tools(hover_tool_p2)
tap2 = TapTool()
p2.add_tools(tap2)
p2_glyph = p2.circle('arbejdstid_timer', 'maanedloen_10aar', size=8, source=source_scatter,
          selection_color="orange", nonselection_alpha=0.3)

# --- JS: Map callback (cross-filter + highlight) ---
map_callback = CustomJS(args=dict(
    source_scatter=source_scatter,
    source_municipalities=source_municipalities,
    dropdown=dropdown,
    search_input=search_input,
    full_data=full_data
), code="""
const geojson = JSON.parse(source_municipalities.geojson);
const inds = cb_obj.indices;

// Toggle selected kommuner
inds.forEach(i => {
    const feat = geojson.features[i];
    if (feat.properties.clickable) feat.properties.selected = !feat.properties.selected;
});

// Update fill colors
geojson.features.forEach(f => {
    if (!f.properties.clickable) f.properties.fill_color = 'lightgrey';
    else if (f.properties.selected) f.properties.fill_color = 'orange';
    else f.properties.fill_color = 'lightblue';
});
source_municipalities.geojson = JSON.stringify(geojson);

// Get selected kommuner
const selected_kommuner = geojson.features
    .filter(f => f.properties.selected)
    .map(f => f.properties.navn.toLowerCase());

const data_all = full_data.data;
const keys = Object.keys(data_all);
const selected_inst = dropdown.value;

const keep = [];
for (let i=0; i<data_all['instkommunetx'].length; i++){
    const row_komm = (data_all['instkommunetx'][i] || '').toLowerCase();
    const row_inst = data_all['hovedinsttx'][i];
    if ((selected_kommuner.length===0 || selected_kommuner.includes(row_komm)) &&
        row_inst === selected_inst) keep.push(i);
}

// Rebuild filtered data
const new_data = {};
for (let k=0; k<keys.length; k++){
    const key = keys[k];
    new_data[key] = keep.map(i => data_all[key][i]);
}
source_scatter.data = new_data;

// Update dropdown options
const inst_set = Array.from(new Set(
    data_all['hovedinsttx'].filter((val,i) =>
        selected_kommuner.length===0 || selected_kommuner.includes((data_all['instkommunetx'][i]||'').toLowerCase()))
)).sort();
dropdown.options = inst_set;
if (inst_set.length>0 && !inst_set.includes(selected_inst)) dropdown.value = inst_set[0];

// Update search completions to match current plot
const titles = Array.from(new Set(new_data['titel'] || [])).sort();
search_input.completions = titles;

source_scatter.change.emit();
""")
patches.data_source.selected.js_on_change('indices', map_callback)

# --- JS: Dropdown callback (cross-filter by map selection) ---
dropdown_callback = CustomJS(args=dict(
    source_scatter=source_scatter,
    full_data=full_data,
    source_municipalities=source_municipalities,
    search_input=search_input
), code="""
const val = cb_obj.value;
const data_all = full_data.data;
const keys = Object.keys(data_all);

// Map selected kommuner
const geojson = JSON.parse(source_municipalities.geojson);
const selected_kommuner = geojson.features
    .filter(f => f.properties.selected)
    .map(f => f.properties.navn.toLowerCase());

const keep = [];
for (let i=0; i<data_all['hovedinsttx'].length; i++){
    const row_inst = data_all['hovedinsttx'][i];
    const row_komm = (data_all['instkommunetx'][i]||'').toLowerCase();
    if (row_inst === val && (selected_kommuner.length===0 || selected_kommuner.includes(row_komm))) keep.push(i);
}

// Rebuild filtered data
const new_data = {};
for (let k=0; k<keys.length; k++){
    const key = keys[k];
    new_data[key] = keep.map(i => data_all[key][i]);
}
source_scatter.data = new_data;

// Update search completions to match current plot
const titles = Array.from(new Set(new_data['titel'] || [])).sort();
search_input.completions = titles;

source_scatter.change.emit();
""")
dropdown.js_on_change('value', dropdown_callback)

# --- JS: Search selects items (same as box/lasso/tap) ---
search_callback = CustomJS(args=dict(source_scatter=source_scatter, search_input=search_input), code="""
const sel_title = search_input.value.trim();
if (!sel_title) return;

const data = source_scatter.data;
const indices = [];
for (let i=0; i<data['titel'].length; i++){
    if (data['titel'][i] === sel_title){
        indices.push(i);
    }
}

// Merge with existing selection
const current = new Set(source_scatter.selected.indices || []);
indices.forEach(i => current.add(i));
source_scatter.selected.indices = Array.from(current);

source_scatter.change.emit();
""")
search_input.js_on_change('value', search_callback)

# --- JS: Reset button (clears everything + zoom) ---
reset_callback = CustomJS(args=dict(
    source_scatter=source_scatter,
    source_municipalities=source_municipalities,
    dropdown=dropdown,
    search_input=search_input,
    full_data=full_data,
    p1=p1, p2=p2
), code="""
const geojson = JSON.parse(source_municipalities.geojson);
geojson.features.forEach(f => {
    f.properties.selected = false;
    f.properties.fill_color = f.properties.clickable ? 'lightblue' : 'lightgrey';
});
source_municipalities.geojson = JSON.stringify(geojson);

const data_all = full_data.data;
source_scatter.data = Object.assign({}, data_all);
source_scatter.selected.indices = [];

const all_insts = Array.from(new Set(data_all['hovedinsttx'])).sort();
dropdown.options = all_insts;
dropdown.value = all_insts[0];

search_input.value = '';
search_input.completions = Array.from(new Set(data_all['titel'])).sort();

p1.reset.emit();
p2.reset.emit();

source_scatter.change.emit();
""")
reset_button.js_on_click(reset_callback)

# --- Layout & save ---
layout = column(row(dropdown, reset_button), search_input, row(map_plot, column(p1, p2)))
output_file("dashboard_map_searchable.html")
save(layout)

print("Dashboard saved: dashboard_map_searchable.html — search integrates with selection, orange highlights, deselect works.")
# Out:
# C:\Users\whart\AppData\Local\Temp\ipykernel_24088\2094733013.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['instkommunetx'] = df_clean['instkommunetx'].astype(str).str.strip()
# C:\Users\whart\AppData\Local\Temp\ipykernel_24088\2094733013.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['hovedinsttx'] = df_clean['hovedinsttx'].astype(str).str.strip()
# C:\Users\whart\AppData\Local\Temp\ipykernel_24088\2094733013.py:28: SettingWithCopyWarning:
# ...

# %% [markdown]
# Simons kode ændret lidt

# %%
#loading:
import pandas as pd
# Import data
df_raw = pd.read_excel('../Data/DATA_UFM_combined.xlsx', header=0)

# Columns to keep
cols = [
    ################## EDUCATION INFORMATION ###########################

    # Names of the education
    'udbud_id',
    'titel',
    'educational_category',
    'displaydocclass',
    'hovedinsttx',

    # Region
    'instregiontx',
    'instkommunetx',

    # Grades coefficients
    'optagne',
    'kvote_1_kvotient',

    ####################### EDUCATIONAL VARIABLES ########################

    # Likert data
    'fagligmiljo_likert',               # Faglit miljø
    'arbmedstud_likert',                # Fagligt miljø
    'medstuderende_likert',             # Fagligt miljø
    'udbytte_undervisning_likert',      # Fagligt miljø
    'socialtmiljo_likert',              # Social miljø og trivsel
    'ensom_likert',                     # Social miljø og trivsel
    'stress_daglig_likert',             # Social miljø og trivsel
    'tilpas_likert',                    # Social miljø og trivsel
    'undervisere_engagerede_likert',    # Undervisere
    'undervisere_feedback_likert',      # Undervisere
    'undervisere_hjaelp_likert',        # Undervisere
    'undervisere_kontakt_likert',       # Undervisere

    # continuous data
    'afbrud',                           # frafald
    'tidsforbrug_p50',                  # tidsforbrug studie
    'tidsforbrug_arbejde',              # tidsforbrug studiejob

    # Undervisnings aktivitet
    'uddaktivitet_opgaver_pct',
    'uddaktivitet_praktik_pct',
    'uddaktivitet_udlandsophold_pct',
    'uddaktivitet_undervisning_pct',

    # Undervisningsform
    'undervisningsform_p1',             # Primær undervisningsform

    ########################## Job data ##################################

    # continuous data
    'arbejdstid_timer',
    'ledighed_nyudd',
    'maanedloen_nyudd',
    'maanedloen_10aar',

    # Likert data
    'ruster_til_job_likert',
    'relevans_overens_udd_job_likert',
]

data = df_raw[cols]

# Remove all udbud_id==999999, as this is the education on national level
data_whole_edu = data[data['udbud_id'] == 999999]
data = data[data['udbud_id'] != 999999]

# Remove the udbud_id column
data = data.drop(columns=['udbud_id'])

data_na = data.copy()
# Remove all rows with missing values
data = data.dropna()

# %%
#stjæler lige simons visualization hehe
# Load mapping and join on 'titel' into the existing `data` dataframe
path = "../Data/education_cluster_mapping.xlsx"

mapping = pd.read_excel(path)

mapping['titel'] = mapping['titel'].astype(str).str.strip()
data_whole_edu['titel'] = data_whole_edu['titel'].astype(str).str.strip()
# Left-join mapping into data (keeps all rows from data)
data_whole_edu = data_whole_edu.merge(mapping, on='titel', how='left', suffixes=('', '_map'))

# %%
#Simons version
# DOCUMENTATION: https://plotly.com/python/treemaps/
import plotly.express as px

dat = data_whole_edu[['titel', 'educational_category', 'cluster_label', 'displaydocclass', 'maanedloen_nyudd', 'maanedloen_10aar', 'socialtmiljo_likert']]
dat = dat.dropna()

# Create the treemap
fig = px.treemap(dat, path=['educational_category', 'cluster_label', 'titel'], values='maanedloen_10aar',
                 color='socialtmiljo_likert',
                 color_continuous_scale='RdBu',
                 title='Treemap of Titles by Educational Category')
fig.update_traces(root_color="lightgrey")
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
# Show the treemap
fig.show()

# %% [markdown]
# Now I'll try to build it to be interactive:

# %% [markdown]
# Version 1:

# %% [markdown]
# Version 2 - let's focus on drill down in plotly

# %% [markdown]
# NY START

# %%
import pandas as pd
# Import data
df_raw = pd.read_excel('../Data/DATA_UFM_combined.xlsx', header=0)

# Columns to keep
cols = [
    ################## EDUCATION INFORMATION ###########################

    # Names of the education
    'udbud_id',
    'titel',
    'educational_category',
    'displaydocclass',
    'hovedinsttx',

    # Region
    'instregiontx',
    'instkommunetx',

    # Grades coefficients
    'optagne',
    'kvote_1_kvotient',

    ####################### EDUCATIONAL VARIABLES ########################

    # Likert data
    'fagligmiljo_likert',               # Faglit miljø
    'arbmedstud_likert',                # Fagligt miljø
    'medstuderende_likert',             # Fagligt miljø
    'udbytte_undervisning_likert',      # Fagligt miljø
    'socialtmiljo_likert',              # Social miljø og trivsel
    'ensom_likert',                     # Social miljø og trivsel
    'stress_daglig_likert',             # Social miljø og trivsel
    'tilpas_likert',                    # Social miljø og trivsel
    'undervisere_engagerede_likert',    # Undervisere
    'undervisere_feedback_likert',      # Undervisere
    'undervisere_hjaelp_likert',        # Undervisere
    'undervisere_kontakt_likert',       # Undervisere

    # continuous data
    'afbrud',                           # frafald
    'tidsforbrug_p50',                  # tidsforbrug studie
    'tidsforbrug_arbejde',              # tidsforbrug studiejob

    # Undervisnings aktivitet
    'uddaktivitet_opgaver_pct',
    'uddaktivitet_praktik_pct',
    'uddaktivitet_udlandsophold_pct',
    'uddaktivitet_undervisning_pct',

    # Undervisningsform
    'undervisningsform_p1',             # Primær undervisningsform

    ########################## Job data ##################################

    # continuous data
    'arbejdstid_timer',
    'ledighed_nyudd',
    'maanedloen_nyudd',
    'maanedloen_10aar',

    # Likert data
    'ruster_til_job_likert',
    'relevans_overens_udd_job_likert',
]

data = df_raw[cols]

# Remove all udbud_id==999999, as this is the education on national level
data_whole_edu = data[data['udbud_id'] == 999999]
data = data[data['udbud_id'] != 999999]

# Remove the udbud_id column
data = data.drop(columns=['udbud_id'])

data_na = data.copy()
# Remove all rows with missing values
data = data.dropna()

# %%
# Load mapping and join on 'titel' into the existing `data` dataframe
path = "../Data/education_cluster_mapping.xlsx"

mapping = pd.read_excel(path)

mapping['titel'] = mapping['titel'].astype(str).str.strip()
data_whole_edu['titel'] = data_whole_edu['titel'].astype(str).str.strip()
# Left-join mapping into data (keeps all rows from data)
data_whole_edu = data_whole_edu.merge(mapping, on='titel', how='left', suffixes=('', '_map'))

# %%
dat = data_whole_edu[['titel', 'educational_category', 'cluster_label', 'displaydocclass', 'maanedloen_nyudd', 'maanedloen_10aar', 'socialtmiljo_likert']]
dat = dat.dropna()

# %%
import pandas as pd
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display, clear_output

# -----------------------------
# DATA PREPARATION
# -----------------------------
# Uses your existing dataframe 'dat'
# Aggregate leaf values (sum maanedloen_10aar per titel/cluster/education)
leaf = (
    dat
    .groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)
    ['maanedloen_10aar']
    .sum()
    .rename(columns={'maanedloen_10aar': 'value'})
)

# Prepare nodes: root -> educational_category -> cluster_label -> titel
nodes = []
# root
nodes.append(dict(id='All', label='All', parent='', value=leaf['value'].sum()))

# educational_category nodes
edu_totals = leaf.groupby('educational_category', as_index=False)['value'].sum()
for _, r in edu_totals.iterrows():
    nodes.append(dict(id=r['educational_category'], label=r['educational_category'], parent='All', value=r['value']))

# cluster_label nodes (under their educational_category)
cluster_totals = leaf.groupby(['educational_category', 'cluster_label'], as_index=False)['value'].sum()
for _, r in cluster_totals.iterrows():
    cid = f"{r['educational_category']}/{r['cluster_label']}"
    nodes.append(dict(id=cid, label=r['cluster_label'], parent=r['educational_category'], value=r['value']))

# leaf (titel) nodes
for _, r in leaf.iterrows():
    cid = f"{r['educational_category']}/{r['cluster_label']}"
    lid = f"{cid}/{r['titel']}"
    nodes.append(dict(id=lid, label=r['titel'], parent=cid, value=r['value']))

# Turn nodes into lists for Plotly
ids = [n['id'] for n in nodes]
labels = [n['label'] for n in nodes]
parents = [n['parent'] for n in nodes]
values = [n['value'] for n in nodes]

# -----------------------------
# INTERACTIVE TREEMAP SETUP
# -----------------------------
UNCHECKED = "☐ "
CHECKED = "☑ "
working_labels = [UNCHECKED + str(l) for l in labels]

# Build a FigureWidget Treemap
fig_w = go.FigureWidget(
    go.Treemap(
        ids=ids,
        labels=working_labels,
        parents=parents,
        values=values,
        branchvalues='total',
        textinfo='label',  # checkbox + label only
        hovertemplate='<b>%{label}</b><br>Value: %{value}<extra></extra>',
        root_color="lightgrey"
    )
)
fig_w.update_layout(title='Interactive Treemap — click boxes to toggle checkbox', margin=dict(t=50, l=25, r=25, b=25))

# -----------------------------
# CHECKBOX BEHAVIOR + OUTPUT
# -----------------------------
out = widgets.Output(layout={'border': '1px solid #ddd', 'padding': '6px', 'max_height': '240px', 'overflow': 'auto'})
with out:
    print("Checked items will appear here when you click boxes.")

selected_idx = set()

def _update_output():
    with out:
        clear_output(wait=True)
        if not selected_idx:
            print("No items selected.")
            return
        print("Selected items (id -> label):")
        for i in sorted(selected_idx):
            print(f"- {ids[i]}  ->  {labels[i]}")

def _update_labels():
    new_labels = []
    for i, lab in enumerate(labels):
        prefix = CHECKED if i in selected_idx else UNCHECKED
        new_labels.append(prefix + str(lab))
    fig_w.data[0].labels = new_labels

def _on_click(trace, points, state):
    if not points.point_inds:
        return
    idx = points.point_inds[0]
    if idx in selected_idx:
        selected_idx.remove(idx)
    else:
        selected_idx.add(idx)
    _update_labels()
    _update_output()

fig_w.data[0].on_click(_on_click)

# -----------------------------
# DISPLAY
# -----------------------------
ui = widgets.VBox([fig_w, widgets.Label("Checked items:"), out])
display(ui)
# Out:
# ...
#     'data': [{'branchvalues': 'total',
#               'hovertemplate': '<b>%{labe…

# %% [markdown]
# Parallel coordinates - working example:

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# ----------------------
# Import data
# ----------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined.xlsx', header=0)

cols = [
    'udbud_id', 'titel',
    'fagligmiljo_likert',
    'arbmedstud_likert',
    'medstuderende_likert',
    'udbytte_undervisning_likert',
    'socialtmiljo_likert',
    'ensom_likert',
    'maanedloen_nyudd'
]

data = df_raw[cols]
data_whole_edu = data[data['udbud_id'] == 999999].drop(columns=['udbud_id'])
data_whole_edu = data_whole_edu.dropna()

# ----------------------
# Function to create parallel coordinates figure
# ----------------------
def create_parcoords(selected_titles=[]):
    # Numeric color array: 1 if selected, 0 if not
    line_colors = [1 if t in selected_titles else 0 for t in data_whole_edu['titel']]

    fig = go.Figure(
        data=[
            go.Parcoords(
                line=dict(
                    color=line_colors,
                    colorscale=[[0, 'lightgrey'], [1, 'firebrick']],
                    cmin=0,
                    cmax=1
                ),
                dimensions=[
                    dict(range=[1, 5], label='Faglig miljø', values=data_whole_edu['fagligmiljo_likert']),
                    dict(range=[1, 5], label='Arb. med stud.', values=data_whole_edu['arbmedstud_likert']),
                    dict(range=[1, 5], label='Medstuderende', values=data_whole_edu['medstuderende_likert']),
                    dict(range=[1, 5], label='Udbytte af undervisning', values=data_whole_edu['udbytte_undervisning_likert']),
                    dict(range=[1, 5], label='Socialt miljø', values=data_whole_edu['socialtmiljo_likert']),
                    dict(range=[1, 5], label='Ensomhed', values=data_whole_edu['ensom_likert']),
                    dict(range=[
                        data_whole_edu['maanedloen_nyudd'].min(),
                        data_whole_edu['maanedloen_nyudd'].max()
                    ],
                    label='Månedsløn (nyudd.)',
                    values=data_whole_edu['maanedloen_nyudd'])
                ]
            )
        ]
    )

    fig.update_layout(
        margin=dict(l=80, r=80, t=40, b=40)
    )
    return fig

# ----------------------
# Dash App
# ----------------------
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H3("Uddannelser – Parallel Coordinates Plot"),
    
    html.Label("Vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in data_whole_edu['titel']],
        multi=True
    ),
    
    dcc.Graph(id='parallel-plot', figure=create_parcoords())
])

# ----------------------
# Callback to update highlighted lines
# ----------------------
@app.callback(
    Output('parallel-plot', 'figure'),
    Input('line-selector', 'value')
)
def update_highlight(selected_titles):
    if selected_titles is None:
        selected_titles = []
    return create_parcoords(selected_titles)

# ----------------------
# Run app
# ----------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# and now I want to try and combine it what we already have (then later we need to refine the treemap, such that selecting works correctly)
# This below works well, but it seems to have been messed up the categories?

# %% [markdown]
# Now I want to combine them so I still have the search bar:

# %% [markdown]
# Let's try to merge it to get the better navigator bar in:
# This version the treemap is broken, but it's a start:

# %% [markdown]
# REALLY GOOD WORKING VERSION - BUT WITH A FEW SELECT ISSUES

# %%
import dash
from dash import dcc, html, Input, Output
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD AND PREPARE DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel',
    'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert',
    'medstuderende_likert', 'udbytte_undervisning_likert',
    'socialtmiljo_likert', 'ensom_likert', 'maanedloen_nyudd'
]

data = df_raw[cols]
data_whole_edu = data[data['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP HIERARCHY
# -----------------------------
dat = data_whole_edu[[
    'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert',
    'medstuderende_likert', 'udbytte_undervisning_likert',
    'socialtmiljo_likert', 'ensom_likert', 'maanedloen_nyudd'
]]

leaf = (
    dat
    .groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)
    .agg({'maanedloen_nyudd': 'mean'})
)

# -----------------------------
# CREATE TREEMAP FIGURE
# -----------------------------
def create_treemap():
    fig = px.treemap(
        leaf,
        path=['educational_category', 'cluster_label', 'titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu',
        title="Treemap over Uddannelser"
    )
    fig.update_layout(margin=dict(t=30, l=10, r=10, b=10))
    return fig

# -----------------------------
# CREATE PARALLEL COORDINATES
# -----------------------------
def create_parcoords(selected_titles=[]):
    line_colors = [1 if t in selected_titles else 0 for t in data_whole_edu['titel']]

    fig = go.Figure(
        data=[
            go.Parcoords(
                line=dict(
                    color=line_colors,
                    colorscale=[[0, 'lightgrey'], [1, 'firebrick']],
                    cmin=0, cmax=1
                ),
                dimensions=[
                    dict(range=[1, 5], label='Faglig miljø', values=data_whole_edu['fagligmiljo_likert']),
                    dict(range=[1, 5], label='Arb. med stud.', values=data_whole_edu['arbmedstud_likert']),
                    dict(range=[1, 5], label='Medstuderende', values=data_whole_edu['medstuderende_likert']),
                    dict(range=[1, 5], label='Udbytte af undervisning', values=data_whole_edu['udbytte_undervisning_likert']),
                    dict(range=[1, 5], label='Socialt miljø', values=data_whole_edu['socialtmiljo_likert']),
                    dict(range=[1, 5], label='Ensomhed', values=data_whole_edu['ensom_likert']),
                    dict(
                        range=[
                            data_whole_edu['maanedloen_nyudd'].min(),
                            data_whole_edu['maanedloen_nyudd'].max()
                        ],
                        label='Månedsløn (nyudd.)',
                        values=data_whole_edu['maanedloen_nyudd']
                    )
                ]
            )
        ]
    )

    fig.update_layout(
        margin=dict(l=80, r=80, t=40, b=40),
        height=600
    )
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H2("Uddannelser – Treemap og Parallel Coordinates"),
    dcc.Graph(id='treemap', figure=create_treemap()),

    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(data_whole_edu['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),

    dcc.Graph(id='parallel-plot', figure=create_parcoords())
], style={'max-width': '1100px', 'margin': '0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector', 'value'),
    Input('treemap', 'clickData'),
    Input('line-selector', 'value')
)
def sync_selection(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []

    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in data_whole_edu['titel'].values:
            if clicked in selected_titles:
                selected_titles.remove(clicked)
            else:
                selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot', 'figure'),
    Input('line-selector', 'value')
)
def update_parallel(selected_titles):
    if selected_titles is None:
        selected_titles = []
    return create_parcoords(selected_titles)

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Keep the version above as a demo, but we keep working on it:
# BELOW IS THE WORKING INTEGRATED VERSION AS IT SHOULD BE FOR PARALLEL COORDINATES

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

data = df_raw[cols]
data_whole_edu = data[data['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()
dat = data_whole_edu.copy()

# -----------------------------
# BUILD TREEMAP FIGURE
# -----------------------------
def create_treemap():
    fig = px.treemap(
        dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)
           .agg({'maanedloen_nyudd':'mean'}),
        path=['educational_category', 'cluster_label', 'titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu',
        title="Treemap over Uddannelser"
    )
    fig.update_layout(margin=dict(t=30, l=10, r=10, b=10), height=400)
    return fig

# -----------------------------
# CREATE PARALLEL COORDINATES
# -----------------------------
def create_parcoords(selected_titles=[]):
    line_colors = [1 if t in selected_titles else 0 for t in dat['titel']]
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(
                    range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                    label='Månedsløn (nyudd.)',
                    values=dat['maanedloen_nyudd']
                )
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

app.layout = html.Div([
    html.H2("Uddannelser – Treemap og Parallel Coordinates"),

    dcc.Graph(id='treemap', figure=create_treemap()),

    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),

    dcc.Graph(id='parallel-plot', figure=create_parcoords())
], style={'max-width':'1100px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
# Click on treemap to add to dropdown selection
@app.callback(
    Output('line-selector', 'value'),
    Input('treemap', 'clickData'),
    State('line-selector', 'value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []

    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        # Only add if it's a leaf node
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

# Update parallel coordinates whenever dropdown selection changes
@app.callback(
    Output('parallel-plot', 'figure'),
    Input('line-selector', 'value')
)
def update_parallel(selected_titles):
    if selected_titles is None:
        selected_titles = []
    return create_parcoords(selected_titles)

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ABOVE IS A VERY GOOD WORKING VERSION - BUT I WANT TO REFINE IT
# SLIDE DEMO BELOW:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)
cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]
data = df_raw[cols]
data_whole_edu = data[data['udbud_id']==999999].drop(columns=['udbud_id']).dropna()
dat = data_whole_edu.copy()

# -----------------------------
# BUILD TREEMAP FIGURE
# -----------------------------
import plotly.express as px
def create_treemap():
    fig = px.treemap(
        dat.groupby(['educational_category','cluster_label','titel'], as_index=False)
           .agg({'maanedloen_nyudd':'mean'}),
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu',
        title="Treemap over Uddannelser"
    )
    fig.update_layout(margin=dict(t=30,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# CREATE PARALLEL COORDINATES
# -----------------------------
def create_parcoords(selected_titles=[], filters={}):
    # Apply filtering by axis ranges
    filtered = dat.copy()
    for col, r in filters.items():
        if r is not None:
            filtered = filtered[(filtered[col]>=r[0]) & (filtered[col]<=r[1])]
    
    line_colors = [1 if t in filtered['titel'].values else 0 for t in dat['titel']]
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig, filtered['titel'].tolist()

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Define slider ranges
slider_dict = {
    'fagligmiljo_likert': [1,5],
    'arbmedstud_likert': [1,5],
    'medstuderende_likert': [1,5],
    'udbytte_undervisning_likert': [1,5],
    'socialtmiljo_likert': [1,5],
    'ensom_likert': [1,5],
    'maanedloen_nyudd': [dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()]
}

app.layout = html.Div([
    html.H2("Uddannelser – Treemap og Parallel Coordinates"),

    dcc.Graph(id='treemap', figure=create_treemap()),

    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),

    html.H4("Filtrer linjer efter akser:"),
    html.Div([
        html.Div([
            html.Label(col.replace('_',' ').title()),
            dcc.RangeSlider(
                id=f'slider-{col}',
                min=slider_dict[col][0],
                max=slider_dict[col][1],
                step=(slider_dict[col][1]-slider_dict[col][0])/100,
                value=[slider_dict[col][0], slider_dict[col][1]],
                marks={slider_dict[col][0]: str(slider_dict[col][0]),
                       slider_dict[col][1]: str(slider_dict[col][1])}
            )
        ], style={'margin':'10px 0'}) for col in slider_dict
    ]),

    html.H4("Parallel Coordinates"),
    dcc.Graph(id='parallel-plot'),

    html.H4("Linjer der matcher filtrering:"),
    html.Div(id='filtered-lines', style={'whiteSpace':'pre-wrap'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Output('filtered-lines','children'),
    [Input('line-selector','value')] +
    [Input(f'slider-{col}','value') for col in slider_dict]
)
def update_parallel(selected_titles, *slider_values):
    filters = {col: val for col, val in zip(slider_dict.keys(), slider_values)}
    fig, filtered_titles = create_parcoords(selected_titles, filters)
    return fig, '\n'.join(filtered_titles)

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# NOW I'LL REFINE THE SLIDERS, PUTTING THEM TO THE RIGHT AND WORKING ON THE TREEMAP LOGIC TO NOT OVERLAP:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

data = df_raw[cols]
data_whole_edu = data[data['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()
dat = data_whole_edu.copy()

# -----------------------------
# BUILD TREEMAP FIGURE
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category','cluster_label','titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu',
        title="Treemap over Uddannelser"
    )
    fig.update_layout(margin=dict(t=30,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# CREATE PARALLEL COORDINATES
# -----------------------------
def create_parcoords(selected_titles=[], slider_filter={}):
    df_filtered = dat.copy()
    # Apply slider filters if any
    for col, (low, high) in slider_filter.items():
        df_filtered = df_filtered[(df_filtered[col] >= low) & (df_filtered[col] <= high)]

    line_colors = [1 if t in selected_titles else 0 for t in df_filtered['titel']]

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=df_filtered['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=df_filtered['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=df_filtered['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=df_filtered['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=df_filtered['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=df_filtered['ensom_likert']),
                dict(range=[df_filtered['maanedloen_nyudd'].min(), df_filtered['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)',
                     values=df_filtered['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Sliders for filtering
slider_components = []
slider_columns = ['fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
                  'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert']
for col in slider_columns:
    slider_components.append(
        html.Div([
            html.Label(col),
            dcc.RangeSlider(
                id={'type':'parcoords-slider','index':col},
                min=dat[col].min(),
                max=dat[col].max(),
                step=0.1,
                value=[dat[col].min(), dat[col].max()],
                tooltip={"placement":"bottom","always_visible":False}
            )
        ], style={'margin-bottom':'15px','width':'250px'})
    )

app.layout = html.Div([
    html.H2("Uddannelser – Treemap og Parallel Coordinates"),

    dcc.Graph(id='treemap', figure=create_treemap()),

    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),

    html.Div([
        dcc.Graph(id='parallel-plot', figure=create_parcoords()),
        html.Div(slider_components, style={'margin-left':'20px','display':'inline-block','verticalAlign':'top'})
    ], style={'display':'flex','align-items':'flex-start'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []

    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        # Only add if it's a leaf node
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'parcoords-slider','index':dash.dependencies.ALL}, 'value')
)
def update_parallel(selected_titles, slider_values):
    if selected_titles is None:
        selected_titles = []

    # Build filter dictionary from sliders
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        slider_filter[col] = (val[0], val[1])

    return create_parcoords(selected_titles, slider_filter)

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu',
        title="Treemap over Uddannelser"
    )
    fig.update_layout(margin=dict(t=30,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = ['fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
                  'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd']

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # dropdown highlight -> firebrick
        elif any(low <= row[col] <= high for col, (low, high) in slider_filter.items()):
            line_colors.append(0.5)  # slider highlight -> royalblue
        else:
            line_colors.append(0.0)  # default -> lightgrey

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'], [0.5,'royalblue'], [1,'firebrick']], cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Create slider components
slider_components = []
for col in slider_columns:
    slider_components.append(
        html.Div([
            html.Label(col),
            dcc.RangeSlider(
                id={'type':'slider','index':col},
                min=dat[col].min(),
                max=dat[col].max(),
                step=(dat[col].max()-dat[col].min())/50,
                value=[dat[col].min(), dat[col].max()],
                tooltip={"placement":"bottom","always_visible":False}
            )
        ], style={'margin-bottom':'10px', 'width':'200px'})
    )

app.layout = html.Div([
    html.H2("Uddannelser – Treemap og Parallel Coordinates"),
    
    dcc.Graph(id='treemap', figure=create_treemap()),

    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0),

    html.Div(slider_components, id='slider-container', style={'display':'none','float':'right','margin-left':'20px'}),

    dcc.Graph(id='parallel-plot')
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            slider_filter[col] = val
    return create_parcoords(selected_titles, slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','float':'right','margin-left':'20px'}
    else:
        return {'display':'none'}

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# welppp

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu',
        title="Treemap over Uddannelser"
    )
    fig.update_layout(margin=dict(t=30,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = ['fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
                  'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd']

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        # Check dropdown selection first
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # red
        # Check slider filters
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.5)  # blue
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)  # grey if nothing selected

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[0.5,'royalblue'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Slider components: start at min=min (so nothing selected)
slider_components = []
for col in slider_columns:
    if col != 'maanedloen_nyudd':  # Likert 1-5
        slider_components.append(
            html.Div([
                html.Label(col),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i: str(i) for i in range(1,6)},
                    tooltip={"placement":"bottom","always_visible":False}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:  # maanedloen continuous
        slider_components.append(
            html.Div([
                html.Label(col),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=dat[col].min(),
                    max=dat[col].max(),
                    step=(dat[col].max()-dat[col].min())/50,
                    value=[dat[col].min(),dat[col].min()],
                    tooltip={"placement":"bottom","always_visible":False}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([
    html.H2("Uddannelser – Treemap og Parallel Coordinates"),
    
    dcc.Graph(id='treemap', figure=create_treemap()),

    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0),

    # Parallel coordinates + sliders side-by-side
    html.Div([
        dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
        html.Div(slider_components, id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
    ])
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            # Only consider if min != max (selection active)
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles, slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    else:
        return {'display':'none'}

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# looks alright, now i'll try to polish it:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = ['fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
                  'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd']

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # firebrick
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.6)  # mild blue for slider match
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors,
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']],
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=10,b=10), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        slider_components.append(
            html.Div([
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=dat[col].min(),
                    max=dat[col].max(),
                    step=(dat[col].max()-dat[col].min())/50,
                    value=[dat[col].min(),dat[col].min()]
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),  # milder blue

    html.Button("Print Matching Titles", id="print-sliders", n_clicks=0),

    html.Div([
        dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
        html.Div(slider_components + [html.Div(id='slider-output')], 
                 id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
    ])
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles, slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('slider-output','children'),
    Input('print-sliders','n_clicks'),
    State({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(n_clicks, slider_values):
    if n_clicks:
        slider_filter = {}
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
        if slider_filter:
            filtered = dat.copy()
            for col, (low, high) in slider_filter.items():
                filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
            if not filtered.empty:
                return html.Div([html.Div(t) for t in filtered['titel'].tolist()])
        return "No matching titles"
    return ""

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# alright, now polish bottom slider and let's run ittt

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # firebrick
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.6)  # mild blue for slider match
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors,
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']],
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=10,b=10), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        # Marks at 20k,30k,40k,50k,60k
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),  # milder blue

    html.Button("Print Matching Titles", id="print-sliders", n_clicks=0),

    html.Div([
        dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
        html.Div(slider_components + [html.Div(id='slider-output')], 
                 id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
    ])
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles, slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('slider-output','children'),
    Input('print-sliders','n_clicks'),
    State({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(n_clicks, slider_values):
    if n_clicks:
        slider_filter = {}
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
        if slider_filter:
            filtered = dat.copy()
            for col, (low, high) in slider_filter.items():
                filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
            if not filtered.empty:
                return html.Div([html.Div(t) for t in filtered['titel'].tolist()])
        return "No matching titles"
    return ""

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# more tests:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # firebrick
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.6)  # mild blue for slider match
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors,
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']],
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=10,b=10), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),

    html.Button("Print Matching Titles", id="print-sliders", n_clicks=0),

    html.Div([
        dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
        html.Div(slider_components + [html.Div(id='slider-output')], 
                 id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
    ])
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles, slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('slider-output','children'),
    Input('print-sliders','n_clicks'),
    State('line-selector','value'),
    State({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(n_clicks, selected_titles, slider_values):
    if n_clicks:
        # Slider filter
        slider_filter = {}
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val

        # Matching titles from sliders
        if slider_filter:
            filtered = dat.copy()
            for col, (low, high) in slider_filter.items():
                filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
            slider_matches = filtered['titel'].tolist()
        else:
            slider_matches = []

        # Display both
        return html.Div([
            html.B("Matching titles from selection:"),
            html.Div([html.Div(t) for t in (selected_titles or ["None"])]),
            html.B("Matching titles from sliders:"),
            html.Div([html.Div(t) for t in (slider_matches or ["None"])])
        ])
    return ""

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# now i'll add colour and slider labels:

# %%
import dash
from dash import dcc, html, Input, Output, State, ALL
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # firebrick
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.6)  # mild blue for slider match
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors,
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']],
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=10,b=10), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                html.Label(col),  # <--- show variable name
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                html.Label(col),  # <--- show variable name
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),

    html.Button("Print Matching Titles", id="print-sliders", n_clicks=0),

    html.Div([
        dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
        html.Div(slider_components + [html.Div(id='slider-output')], 
                 id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
    ])
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles, slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('slider-output','children'),
    Input('print-sliders','n_clicks'),
    State('line-selector','value'),
    State({'type':'slider','index':ALL}, 'value')
)
def print_matching_titles(n_clicks, selected_titles, slider_values):
    # Slider filter
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val

    # Matching titles from sliders
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered['titel'].tolist()
    else:
        slider_matches = []

    # Display both, coloring the titles themselves
    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div([html.Div(t, style={'color':'firebrick'}) for t in (selected_titles or ["None"])]),
        html.B("Matching titles from sliders:"),
        html.Div([html.Div(t, style={'color':'#87CEFA'}) for t in (slider_matches or ["None"])])
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# now i'll try to add the urls:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd', 'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # firebrick
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.6)  # mild blue
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors,
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']],
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=10,b=10), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    label = col.replace('_', ' ').capitalize()
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                html.Label(label),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                html.Label("Månedsløn"),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),

    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(slider_components + [html.Div(id='slider-output')], 
                       id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
             ]),

    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:  # only apply slider filtering if toggled on
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    # Always show plot; no empty state
    return create_parcoords(selected_titles or [], slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(selected_titles, slider_values):
    # Slider filter
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val

    # Matching titles from sliders
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered[['titel','url']].to_dict('records')
    else:
        slider_matches = []

    # Matching titles from selection
    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    def create_links(records, color):
        return [html.Div(html.A(r['titel'], href=r['url'], target="_blank", style={'color':color})) for r in records] or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# and another iteration:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd', 'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # firebrick
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.6)  # mild blue for slider match
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors,
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']],
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=10,b=10), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                html.Label(col),  # show slider name
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                html.Label(col),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),

    html.Div([
        dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
        html.Div(slider_components + [html.Div(id='slider-output')], 
                 id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
    ])
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles, slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('slider-output','children'),
    Input('line-selector','value'),
    State({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(selected_titles, slider_values):
    # -----------------------------
    # Slider filter
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val

    # Matching titles from sliders
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered.to_dict('records')
    else:
        slider_matches = []

    # Matching titles from selection
    selected_records = dat[dat['titel'].isin(selected_titles)].to_dict('records') if selected_titles else []

    # Function to make clickable links with correct scheme
    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url  # prepend https://
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# now links work, but the printing is messed up, I continue:
# below is my beautiful currently working version:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd', 'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)  # firebrick
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            if match:
                line_colors.append(0.6)  # mild blue
            else:
                line_colors.append(0.0)  # grey
        else:
            line_colors.append(0.0)
    
    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors,
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']],
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=10,b=10), height=500)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    label = col.replace('_', ' ').capitalize()
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                html.Label(label),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                html.Label("Månedsløn"),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),

    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(slider_components + [html.Div(id='slider-output')], 
                       id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
             ]),

    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles or [], slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(selected_titles, slider_values):
    # Slider filter
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val

    # Matching titles from sliders
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered[['titel','url']].to_dict('records')
    else:
        slider_matches = []

    # Matching titles from selection
    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    # Create clickable links with https:// prefix if missing
    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# now i'll try and make parallel coordinates beautiful again:

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd', 'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    # Line coloring: red for selected, blue for slider match, grey otherwise
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            line_colors.append(0.6 if match else 0.0)
        else:
            line_colors.append(0.0)

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, 
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']], 
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    label = col.replace('_', ' ').capitalize()
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                html.Label(label),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                html.Label("Månedsløn"),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    html.Button("Toggle Sliders", id="toggle-sliders", n_clicks=0, 
                style={'background-color':'#87CEFA'}),

    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(slider_components + [html.Div(id='slider-output')], 
                       id='slider-container', style={'display':'none','width':'22%','float':'right','margin-left':'2%'})
             ]),

    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value'),
    Input('toggle-sliders','n_clicks')
)
def update_parcoords(selected_titles, slider_values, toggle):
    slider_filter = {}
    if toggle % 2 == 1:
        for col, val in zip(slider_columns, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    return create_parcoords(selected_titles or [], slider_filter)

@app.callback(
    Output('slider-container','style'),
    Input('toggle-sliders','n_clicks')
)
def toggle_slider_visibility(n_clicks):
    if n_clicks % 2 == 1:
        return {'display':'block','width':'22%','float':'right','margin-left':'2%'}
    return {'display':'none'}

@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(selected_titles, slider_values):
    # Slider filter
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val

    # Matching titles from sliders
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered[['titel','url']].to_dict('records')
    else:
        slider_matches = []

    # Matching titles from selection
    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    # Create clickable links with https:// prefix if missing
    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# I like the sliders, so I'll make them there all the time:
# THIS IS THE BEST CURRENT WORKING VERSION

# %%
import dash
from dash import dcc, html, Input, Output, State
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'maanedloen_nyudd', 'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label', 'titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# PARALLEL COORDINATES
# -----------------------------
slider_columns = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert',
    'udbytte_undervisning_likert','socialtmiljo_likert','ensom_likert','maanedloen_nyudd'
]

def create_parcoords(selected_titles=[], slider_filter={}):
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            line_colors.append(0.6 if match else 0.0)
        else:
            line_colors.append(0.0)

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, 
                      colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']], 
                      cmin=0, cmax=1),
            dimensions=[
                dict(range=[1,5], label='Faglig miljø', values=dat['fagligmiljo_likert']),
                dict(range=[1,5], label='Arb. med stud.', values=dat['arbmedstud_likert']),
                dict(range=[1,5], label='Medstuderende', values=dat['medstuderende_likert']),
                dict(range=[1,5], label='Udbytte undervisning', values=dat['udbytte_undervisning_likert']),
                dict(range=[1,5], label='Socialt miljø', values=dat['socialtmiljo_likert']),
                dict(range=[1,5], label='Ensomhed', values=dat['ensom_likert']),
                dict(range=[dat['maanedloen_nyudd'].min(), dat['maanedloen_nyudd'].max()],
                     label='Månedsløn (nyudd.)', values=dat['maanedloen_nyudd'])
            ]
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

slider_components = []
for col in slider_columns:
    label = col.replace('_', ' ').capitalize()
    if col != 'maanedloen_nyudd':
        slider_components.append(
            html.Div([
                html.Label(label),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=1,
                    max=5,
                    step=0.1,
                    value=[1,1],
                    marks={i:str(i) for i in range(1,6)}
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )
    else:
        min_val = dat[col].min()
        max_val = dat[col].max()
        step_val = (max_val - min_val)/50
        marks = {i: f"{i:,}" for i in [20000,30000,40000,50000,60000] if i <= max_val}
        slider_components.append(
            html.Div([
                html.Label("Månedsløn"),
                dcc.RangeSlider(
                    id={'type':'slider','index':col},
                    min=min_val,
                    max=max_val,
                    step=step_val,
                    value=[min_val,min_val],
                    marks=marks
                )
            ], style={'margin-bottom':'10px','width':'180px'})
        )

app.layout = html.Div([

    dcc.Graph(id='treemap', figure=create_treemap()),

    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg..."
    ),

    # Parallel coordinates + sliders always visible
    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(slider_components + [html.Div(id='slider-output')], 
                       id='slider-container', style={'width':'22%','float':'right','margin-left':'2%'})
             ]),

    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value')
)
def update_parcoords(selected_titles, slider_values):
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val
    return create_parcoords(selected_titles or [], slider_filter)

@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':dash.ALL}, 'value')
)
def print_matching_titles(selected_titles, slider_values):
    slider_filter = {}
    for col, val in zip(slider_columns, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val

    filtered = dat.copy()
    for col, (low, high) in slider_filter.items():
        filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
    slider_matches = filtered[['titel','url']].to_dict('records') if slider_filter else []

    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Now I want to self select the variables for the parallel coordinates plot - let's try:

# %%
import dash
from dash import dcc, html, Input, Output, State, ALL
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'stress_daglig_likert', 'tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert',
    'undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar',
    'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# VARIABLES FOR PARCOORDS
# -----------------------------
all_variables = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert','udbytte_undervisning_likert',
    'socialtmiljo_likert','ensom_likert','stress_daglig_likert','tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert','undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar'
]

default_vars = all_variables[:5]  # Start with first 5 variables

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label','titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# CREATE PARCOORDS FIGURE
# -----------------------------
def create_parcoords(selected_titles=[], slider_filter={}, selected_vars=None):
    if selected_vars is None:
        selected_vars = default_vars

    # Build line colors
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            line_colors.append(0.6 if match else 0.0)
        else:
            line_colors.append(0.0)

    # Build dimensions dynamically
    dimensions = []
    for col in selected_vars:
        values = dat[col]
        if values.max() > 5:  # Continuous
            dim = dict(range=[values.min(), values.max()], label=col, values=values)
        else:  # Likert 1-5
            dim = dict(range=[1,5], label=col, values=values)
        dimensions.append(dim)

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=dimensions
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Dropdown to select variables
variable_selector = dcc.Dropdown(
    id='variable-selector',
    options=[{'label': v, 'value': v} for v in all_variables],
    value=default_vars,
    multi=True,
    placeholder="Select variables for parallel coordinates"
)

# Sliders will be generated dynamically based on selected variables
def generate_sliders(selected_vars):
    slider_components = []
    for col in selected_vars:
        if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
            # Likert 1-5
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=1,
                        max=5,
                        step=0.1,
                        value=[1,1],
                        marks={i:str(i) for i in range(1,6)}
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
        else:
            # Continuous
            min_val = dat[col].min()
            max_val = dat[col].max()
            step_val = (max_val-min_val)/50
            marks = {int(i): str(int(i)) for i in [20000,30000,40000,50000,60000] if i <= max_val}
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=min_val,
                        max=max_val,
                        step=step_val,
                        value=[min_val,min_val],
                        marks=marks
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
    return slider_components

app.layout = html.Div([
    dcc.Graph(id='treemap', figure=create_treemap()),
    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),
    html.Label("Vælg variabler for parallel coordinates:"),
    variable_selector,
    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(id='slider-container', style={'width':'22%','float':'right','margin-left':'2%'})
             ]),
    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Output('slider-container','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    Input('variable-selector', 'value')
)
def update_parcoords(selected_titles, slider_values, selected_vars):
    slider_filter = {}
    if slider_values:
        for col, val in zip(selected_vars, slider_values):
            if val[0] != val[1]:
                slider_filter[col] = val
    sliders = generate_sliders(selected_vars)
    fig = create_parcoords(selected_titles or [], slider_filter, selected_vars)
    return fig, sliders

@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value')
)
def print_matching_titles(selected_titles, slider_values):
    slider_filter = {}
    for col, val in zip(all_variables, slider_values):
        if val[0] != val[1]:
            slider_filter[col] = val

    filtered = dat.copy()
    for col, (low, high) in slider_filter.items():
        filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
    slider_matches = filtered[['titel','url']].to_dict('records') if slider_filter else []

    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# FINAL WORKING VERSION FOR NOW:

# %%
import dash
from dash import dcc, html, Input, Output, State, ALL
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'stress_daglig_likert', 'tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert',
    'undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar',
    'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# VARIABLES FOR PARCOORDS
# -----------------------------
all_variables = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert','udbytte_undervisning_likert',
    'socialtmiljo_likert','ensom_likert','stress_daglig_likert','tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert','undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar'
]

default_vars = all_variables[:5]  # Start with first 5 variables

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label','titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='RdBu'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# CREATE PARCOORDS FIGURE
# -----------------------------
def create_parcoords(selected_titles=[], slider_filter={}, selected_vars=None):
    if selected_vars is None:
        selected_vars = default_vars

    # Build line colors
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            line_colors.append(0.6 if match else 0.0)
        else:
            line_colors.append(0.0)

    # Build dimensions dynamically
    dimensions = []
    for col in selected_vars:
        values = dat[col]
        if values.max() > 5:  # Continuous
            dim = dict(range=[values.min(), values.max()], label=col, values=values)
        else:  # Likert 1-5
            dim = dict(range=[1,5], label=col, values=values)
        dimensions.append(dim)

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=dimensions
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Dropdown to select variables
variable_selector = dcc.Dropdown(
    id='variable-selector',
    options=[{'label': v, 'value': v} for v in all_variables],
    value=default_vars,
    multi=True,
    placeholder="Select variables for parallel coordinates"
)

# Sliders will be generated dynamically based on selected variables
def generate_sliders(selected_vars):
    slider_components = []
    for col in selected_vars:
        if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
            # Likert 1-5
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=1,
                        max=5,
                        step=0.1,
                        value=[1,1],
                        marks={i:str(i) for i in range(1,6)}
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
        else:
            # Continuous
            min_val = dat[col].min()
            max_val = dat[col].max()
            step_val = (max_val-min_val)/50
            marks = {int(i): str(int(i)) for i in [20000,30000,40000,50000,60000] if i <= max_val}
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=min_val,
                        max=max_val,
                        step=step_val,
                        value=[min_val,min_val],
                        marks=marks
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
    return slider_components

app.layout = html.Div([
    dcc.Graph(id='treemap', figure=create_treemap()),
    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),
    html.Label("Vælg variabler for parallel coordinates:"),
    variable_selector,
    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(id='slider-container', style={'width':'22%','float':'right','margin-left':'2%'})
             ]),
    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Output('slider-container','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    Input('variable-selector', 'value'),
    State({'type':'slider','index':ALL}, 'id'),
    State({'type':'slider','index':ALL}, 'value')
)
def update_parcoords(selected_titles, slider_values, selected_vars, slider_ids, slider_states):
    # Map previous slider values
    prev_values = {s['index']: v for s, v in zip(slider_ids, slider_states)} if slider_ids else {}

    sliders = []
    slider_filter = {}

    for col in selected_vars:
        # Determine current slider value: keep previous if exists, else default
        if col in prev_values:
            val = prev_values[col]
        else:
            if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
                val = [1,1]
            else:
                val = [dat[col].min(), dat[col].min()]

        # Add to filter if not default
        if val[0] != val[1]:
            slider_filter[col] = val

        # Build slider component
        if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
            sliders.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=1,
                        max=5,
                        step=0.1,
                        value=val,
                        marks={i:str(i) for i in range(1,6)}
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
        else:
            min_val = dat[col].min()
            max_val = dat[col].max()
            step_val = (max_val - min_val)/50
            marks = {int(i): str(int(i)) for i in [20000,30000,40000,50000,60000] if i <= max_val}
            sliders.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=min_val,
                        max=max_val,
                        step=step_val,
                        value=val,
                        marks=marks
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )

    fig = create_parcoords(selected_titles or [], slider_filter, selected_vars)
    return fig, sliders


@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    State({'type':'slider','index':ALL}, 'id')
)
def print_matching_titles(selected_titles, slider_values, slider_ids):
    # Build slider filter dynamically
    slider_filter = {s['index']: val for s, val in zip(slider_ids, slider_values) if val[0] != val[1]}

    # Matching titles from sliders
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered[['titel','url']].to_dict('records')
    else:
        slider_matches = []

    # Matching titles from selection
    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    # Clickable links
    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])


# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Viridis colour scale for extra points:

# %%
import dash
from dash import dcc, html, Input, Output, State, ALL
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd

# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'stress_daglig_likert', 'tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert',
    'undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar',
    'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# VARIABLES FOR PARCOORDS
# -----------------------------
all_variables = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert','udbytte_undervisning_likert',
    'socialtmiljo_likert','ensom_likert','stress_daglig_likert','tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert','undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar'
]

default_vars = all_variables[:5]  # Start with first 5 variables

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap():
    leaf = dat.groupby(['educational_category', 'cluster_label','titel'], as_index=False)\
              .agg({'maanedloen_nyudd':'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values='maanedloen_nyudd',
        color='maanedloen_nyudd',
        color_continuous_scale='Viridis'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# CREATE PARCOORDS FIGURE
# -----------------------------
def create_parcoords(selected_titles=[], slider_filter={}, selected_vars=None):
    if selected_vars is None:
        selected_vars = default_vars

    # Build line colors
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            line_colors.append(0.6 if match else 0.0)
        else:
            line_colors.append(0.0)

    # Build dimensions dynamically
    dimensions = []
    for col in selected_vars:
        values = dat[col]
        if values.max() > 5:  # Continuous
            dim = dict(range=[values.min(), values.max()], label=col, values=values)
        else:  # Likert 1-5
            dim = dict(range=[1,5], label=col, values=values)
        dimensions.append(dim)

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=dimensions
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Dropdown to select variables
variable_selector = dcc.Dropdown(
    id='variable-selector',
    options=[{'label': v, 'value': v} for v in all_variables],
    value=default_vars,
    multi=True,
    placeholder="Select variables for parallel coordinates"
)

# Sliders will be generated dynamically based on selected variables
def generate_sliders(selected_vars):
    slider_components = []
    for col in selected_vars:
        if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
            # Likert 1-5
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=1,
                        max=5,
                        step=0.1,
                        value=[1,1],
                        marks={i:str(i) for i in range(1,6)}
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
        else:
            # Continuous
            min_val = dat[col].min()
            max_val = dat[col].max()
            step_val = (max_val-min_val)/50
            marks = {int(i): str(int(i)) for i in [20000,30000,40000,50000,60000] if i <= max_val}
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=min_val,
                        max=max_val,
                        step=step_val,
                        value=[min_val,min_val],
                        marks=marks
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
    return slider_components

app.layout = html.Div([
    dcc.Graph(id='treemap', figure=create_treemap()),
    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),
    html.Label("Vælg variabler for parallel coordinates:"),
    variable_selector,
    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(id='slider-container', style={'width':'22%','float':'right','margin-left':'2%'})
             ]),
    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Output('slider-container','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    Input('variable-selector', 'value'),
    State({'type':'slider','index':ALL}, 'id'),
    State({'type':'slider','index':ALL}, 'value')
)
def update_parcoords(selected_titles, slider_values, selected_vars, slider_ids, slider_states):
    # Map previous slider values
    prev_values = {s['index']: v for s, v in zip(slider_ids, slider_states)} if slider_ids else {}

    sliders = []
    slider_filter = {}

    for col in selected_vars:
        # Determine current slider value: keep previous if exists, else default
        if col in prev_values:
            val = prev_values[col]
        else:
            if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
                val = [1,1]
            else:
                val = [dat[col].min(), dat[col].min()]

        # Add to filter if not default
        if val[0] != val[1]:
            slider_filter[col] = val

        # Build slider component
        if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
            sliders.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=1,
                        max=5,
                        step=0.1,
                        value=val,
                        marks={i:str(i) for i in range(1,6)}
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
        else:
            min_val = dat[col].min()
            max_val = dat[col].max()
            step_val = (max_val - min_val)/50
            marks = {int(i): str(int(i)) for i in [20000,30000,40000,50000,60000] if i <= max_val}
            sliders.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=min_val,
                        max=max_val,
                        step=step_val,
                        value=val,
                        marks=marks
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )

    fig = create_parcoords(selected_titles or [], slider_filter, selected_vars)
    return fig, sliders


@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    State({'type':'slider','index':ALL}, 'id')
)
def print_matching_titles(selected_titles, slider_values, slider_ids):
    # Build slider filter dynamically
    slider_filter = {s['index']: val for s, val in zip(slider_ids, slider_values) if val[0] != val[1]}

    # Matching titles from sliders
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered[['titel','url']].to_dict('records')
    else:
        slider_matches = []

    # Matching titles from selection
    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    # Clickable links
    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])


# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# nevermind I got another idea - why not select variables for the treemap too lol

# %%
import dash
from dash import dcc, html, Input, Output, State, ALL
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd


# -----------------------------
# LOAD DATA
# -----------------------------
df_raw = pd.read_excel('../Data/DATA_UFM_combined_cluster.xlsx', header=0)

cols = [
    'udbud_id', 'titel', 'educational_category', 'cluster_label',
    'fagligmiljo_likert', 'arbmedstud_likert', 'medstuderende_likert',
    'udbytte_undervisning_likert', 'socialtmiljo_likert', 'ensom_likert',
    'stress_daglig_likert', 'tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert',
    'undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar',
    'url'
]

dat = df_raw[cols]
dat = dat[dat['udbud_id'] == 999999].drop(columns=['udbud_id']).dropna()

# -----------------------------
# VARIABLES FOR PARCOORDS
# -----------------------------
all_variables = [
    'fagligmiljo_likert','arbmedstud_likert','medstuderende_likert','udbytte_undervisning_likert',
    'socialtmiljo_likert','ensom_likert','stress_daglig_likert','tilpas_likert',
    'undervisere_engagerede_likert','undervisere_feedback_likert','undervisere_hjaelp_likert','undervisere_kontakt_likert',
    'afbrud','tidsforbrug_p50','tidsforbrug_arbejde',
    'arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar'
]

default_vars = all_variables[:5]  # Start with first 5 variables

# -----------------------------
# BUILD TREEMAP
# -----------------------------
def create_treemap(color_var='maanedloen_nyudd'):
    leaf = dat.groupby(['educational_category', 'cluster_label','titel'], as_index=False)\
              .agg({color_var:'mean'})
    fig = px.treemap(
        leaf,
        path=['educational_category','cluster_label','titel'],
        values=color_var,
        color=color_var,
        color_continuous_scale='viridis'
    )
    fig.update_layout(margin=dict(t=10,l=10,r=10,b=10), height=400)
    return fig

# -----------------------------
# CREATE PARCOORDS FIGURE
# -----------------------------
def create_parcoords(selected_titles=[], slider_filter={}, selected_vars=None):
    if selected_vars is None:
        selected_vars = default_vars

    # Build line colors
    line_colors = []
    for _, row in dat.iterrows():
        if row['titel'] in selected_titles:
            line_colors.append(1.0)
        elif slider_filter:
            match = True
            for col, (low, high) in slider_filter.items():
                if not (low <= row[col] <= high):
                    match = False
                    break
            line_colors.append(0.6 if match else 0.0)
        else:
            line_colors.append(0.0)

    # Build dimensions dynamically
    dimensions = []
    for col in selected_vars:
        values = dat[col]
        if values.max() > 5:  # Continuous
            dim = dict(range=[values.min(), values.max()], label=col, values=values)
        else:  # Likert 1-5
            dim = dict(range=[1,5], label=col, values=values)
        dimensions.append(dim)

    fig = go.Figure(
        go.Parcoords(
            line=dict(color=line_colors, colorscale=[[0,'lightgrey'],[0.6,'#87CEFA'],[1,'firebrick']], cmin=0, cmax=1),
            dimensions=dimensions
        )
    )
    fig.update_layout(margin=dict(l=80,r=80,t=40,b=40), height=600)
    return fig

# -----------------------------
# DASH APP
# -----------------------------
app = dash.Dash(__name__)

# Dropdown to select variables for treemap coloring (single selection)
treemap_variable_selector = dcc.Dropdown(
    id='treemap-variable-selector',
    options=[{'label': v, 'value': v} for v in all_variables],
    value='maanedloen_nyudd',
    multi=False,
    placeholder="Select variable for treemap color"
)

# Dropdown to select variables for parallel coordinates
variable_selector = dcc.Dropdown(
    id='variable-selector',
    options=[{'label': v, 'value': v} for v in all_variables],
    value=default_vars,
    multi=True,
    placeholder="Select variables for parallel coordinates"
)

# Sliders will be generated dynamically based on selected variables
def generate_sliders(selected_vars):
    slider_components = []
    for col in selected_vars:
        if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
            # Likert 1-5
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=1,
                        max=5,
                        step=0.1,
                        value=[1,1],
                        marks={i:str(i) for i in range(1,6)}
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
        else:
            # Continuous
            min_val = dat[col].min()
            max_val = dat[col].max()
            step_val = (max_val-min_val)/50
            marks = {int(i): str(int(i)) for i in [20000,30000,40000,50000,60000] if i <= max_val}
            slider_components.append(
                html.Div([
                    html.Label(col),
                    dcc.RangeSlider(
                        id={'type':'slider','index':col},
                        min=min_val,
                        max=max_val,
                        step=step_val,
                        value=[min_val,min_val],
                        marks=marks
                    )
                ], style={'margin-bottom':'10px','width':'180px'})
            )
    return slider_components

# -----------------------------
# LAYOUT
# -----------------------------
app.layout = html.Div([
    html.Label("Vælg variabel for treemap farve:"),
    treemap_variable_selector,
    dcc.Graph(id='treemap', figure=create_treemap()),
    html.Label("Søg og vælg uddannelser at fremhæve:"),
    dcc.Dropdown(
        id='line-selector',
        options=[{'label': t, 'value': t} for t in sorted(dat['titel'].unique())],
        multi=True,
        placeholder="Søg efter titel..."
    ),
    html.Label("Vælg variabler for parallel coordinates:"),
    variable_selector,
    html.Div([dcc.Graph(id='parallel-plot', style={'width':'75%','display':'inline-block'}),
              html.Div(id='slider-container', style={'width':'22%','float':'right','margin-left':'2%'})
             ]),
    html.Div(id='matching-titles-output', style={'margin-top':'20px'})
], style={'max-width':'1200px','margin':'0 auto'})

# -----------------------------
# CALLBACKS
# -----------------------------
@app.callback(
    Output('treemap','figure'),
    Input('treemap-variable-selector','value')
)
def update_treemap(color_var):
    return create_treemap(color_var)

@app.callback(
    Output('line-selector','value'),
    Input('treemap','clickData'),
    State('line-selector','value')
)
def treemap_click(clickData, selected_titles):
    if selected_titles is None:
        selected_titles = []
    if clickData and 'points' in clickData:
        clicked = clickData['points'][0]['label']
        if clicked in dat['titel'].values and clicked not in selected_titles:
            selected_titles.append(clicked)
    return selected_titles

@app.callback(
    Output('parallel-plot','figure'),
    Output('slider-container','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    Input('variable-selector', 'value'),
    State({'type':'slider','index':ALL}, 'id'),
    State({'type':'slider','index':ALL}, 'value')
)
def update_parcoords(selected_titles, slider_values, selected_vars, slider_ids, slider_states):
    prev_values = {s['index']: v for s, v in zip(slider_ids, slider_states)} if slider_ids else {}
    sliders = []
    slider_filter = {}

    for col in selected_vars:
        val = prev_values.get(col, [1,1] if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar'] else [dat[col].min(), dat[col].min()])
        if val[0] != val[1]:
            slider_filter[col] = val

        if col not in ['afbrud','tidsforbrug_p50','tidsforbrug_arbejde','arbejdstid_timer','ledighed_nyudd','maanedloen_nyudd','maanedloen_10aar']:
            sliders.append(
                html.Div([html.Label(col), dcc.RangeSlider(id={'type':'slider','index':col}, min=1, max=5, step=0.1, value=val, marks={i:str(i) for i in range(1,6)})], style={'margin-bottom':'10px','width':'180px'})
            )
        else:
            min_val, max_val = dat[col].min(), dat[col].max()
            step_val = (max_val - min_val)/50
            marks = {int(i): str(int(i)) for i in [20000,30000,40000,50000,60000] if i <= max_val}
            sliders.append(
                html.Div([html.Label(col), dcc.RangeSlider(id={'type':'slider','index':col}, min=min_val, max=max_val, step=step_val, value=val, marks=marks)], style={'margin-bottom':'10px','width':'180px'})
            )

    fig = create_parcoords(selected_titles or [], slider_filter, selected_vars)
    return fig, sliders

@app.callback(
    Output('matching-titles-output','children'),
    Input('line-selector','value'),
    Input({'type':'slider','index':ALL}, 'value'),
    State({'type':'slider','index':ALL}, 'id')
)
def print_matching_titles(selected_titles, slider_values, slider_ids):
    slider_filter = {s['index']: val for s, val in zip(slider_ids, slider_values) if val[0] != val[1]}
    if slider_filter:
        filtered = dat.copy()
        for col, (low, high) in slider_filter.items():
            filtered = filtered[(filtered[col] >= low) & (filtered[col] <= high)]
        slider_matches = filtered[['titel','url']].to_dict('records')
    else:
        slider_matches = []

    selected_records = dat[dat['titel'].isin(selected_titles)][['titel','url']].to_dict('records') if selected_titles else []

    def create_links(records, color):
        links = []
        for r in records:
            url = r['url']
            if not url.startswith('http'):
                url = 'https://' + url
            links.append(html.Div(html.A(r['titel'], href=url, target="_blank", style={'color':color})))
        return links or [html.Div("None")]

    return html.Div([
        html.B("Matching titles from selection:"),
        html.Div(create_links(selected_records, 'firebrick')),
        html.B("Matching titles from sliders:"),
        html.Div(create_links(slider_matches, '#87CEFA'))
    ])

# -----------------------------
# RUN APP
# -----------------------------
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# we could carry the viridis selection from the top over to the bottom but with low opacity. may just be confusing though.

# %% [markdown]
# bugfixes for later - native brushing and linking is still there - and it's just in the way
# Also needs to be incorporated with bachelor/kandidat valg ift hvordan vi håndtere det.
# And while I don't think hovering is natively supported, I would love some kind of way in parallel coordinates to show which row it is
#
# some scales are off on the sliders - shows all values instead of rounding, probably needs to be fixed.
# - also probably right label differently
# - to make clear that ledighed is percentage - maanedsløn is kroner etc
#
# for the top - for some reason "afbrud" doesn't work
# - possibly it would be nice to not reorder the tree upon selection, but only highlight with the chosen one? - could be smoother?
#
# there also seems to be a bug, where if you've added a variable to the parallel coordinates plot - and moved it, then upon using its slider it snaps back to the most right (where it would appear if it was newly selected) - not the position we moved it to. - I probably need to fix the order in which it updates in

# %% [markdown]
# Hovering ability doesn't seem to work sadly
