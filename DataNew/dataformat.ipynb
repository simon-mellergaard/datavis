# %% [markdown]
# # Formatting file
#
# The purpose of this notebook is only to test formatting, and the actual formatting should go in the dataFormat.py script instead. It should not write to any file.
